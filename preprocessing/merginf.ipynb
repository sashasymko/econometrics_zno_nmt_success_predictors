# %%
import pandas as pd

# %%
df1 = pd.read_parquet('data2020_parquet.parquet')
df2 = pd.read_parquet('data2021_parquet.parquet')
df3 = pd.read_parquet('data2022_parquet.parquet')
df4 = pd.read_parquet('data2023_parquet.parquet')

# %%
df1
# Out:
#        Birth  SexType                     SchoolType  \
# 0       2002        0  середня загальноосвітня школа
# 1       2003        1  середня загальноосвітня школа
# 2       2002        1  середня загальноосвітня школа
# 3       2003        1  середня загальноосвітня школа
# 4       2002        0                       гімназія
# ...      ...      ...                            ...
# 60148   2003        1                          ліцей
# 60149   2003        0                          ліцей
# 60150   2003        1            заклад вищої освіти
# 60151   2003        0            заклад вищої освіти
# 60152   2003        0  середня загальноосвітня школа
#
#                    SchoolRegion                         SchoolArea    Ukr  \
# 0            Рівненська область                  Сарненський район  165,0
# 1               Сумська область       м.Суми. Зарічний район міста  159,0
# 2      Дніпропетровська область                        м.Павлоград    0,0
# ...

# %%
df2
# Out:
#         Birth  SexType                        SchoolType  \
# 0        2003        1  заклад фахової передвищої освіти
# 1        2003        1                             ліцей
# 2        2004        0                             ліцей
# 3        2003        0                             ліцей
# 4        2004        0     середня загальноосвітня школа
# ...       ...      ...                               ...
# 238291   2003        0     середня загальноосвітня школа
# 238292   2004        1     середня загальноосвітня школа
# 238293   2003        1     середня загальноосвітня школа
# 238294   2003        1                             ліцей
# 238295   2004        1     середня загальноосвітня школа
#
#                      SchoolRegion                              SchoolArea  \
# 0        Дніпропетровська область  м.Кам'янське. Дніпровський район міста
# 1          Кіровоградська область  м.Кропивницький. Фортечний район міста
# ...

# %%
df3
# Out:
#         Birth  SexType                     SchoolType       SchoolRegion  \
# 0        2005        1    навчально-виховний комплекс  Львівська область
# 1        2005        1    навчально-виховний комплекс  Львівська область
# 2        2005        0    навчально-виховний комплекс  Львівська область
# 3        2005        0    навчально-виховний комплекс  Львівська область
# 4        2005        1    навчально-виховний комплекс  Львівська область
# ...       ...      ...                            ...                ...
# 214069   2005        0  середня загальноосвітня школа  Волинська область
# 214070   2005        1  середня загальноосвітня школа  Волинська область
# 214071   2005        0  середня загальноосвітня школа  Волинська область
# 214072   2005        1  середня загальноосвітня школа  Волинська область
# 214073   2004        0  середня загальноосвітня школа  Волинська область
#
#                   SchoolArea TestType    Ukr   Hist   Math  Phys  Chem  Bio  \
# ...

# %%
df4
# Out:
#         Birth  SexType                                        SchoolType  \
# 0        2006        0                                          гімназія
# 1        2006        0                                          гімназія
# 2        2006        0                       навчально-виховний комплекс
# 3        2003        0                                              None
# 4        2006        1                       навчально-виховний комплекс
# ...       ...      ...                                               ...
# 268123   2006        1                     середня загальноосвітня школа
# 268124   2004        1                                              None
# 268125   2006        0                     середня загальноосвітня школа
# 268126   2004        1  заклад професійної (професійно-технічної) освіти
# 268127   2006        1                                             ліцей
#
#                     SchoolRegion          SchoolArea TestType    Ukr   Hist  \
# ...

# %%
merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True, sort=False)
merged_df
# Out:
#         Birth  SexType                                        SchoolType  \
# 0        2002        0                     середня загальноосвітня школа
# 1        2003        1                     середня загальноосвітня школа
# 2        2002        1                     середня загальноосвітня школа
# 3        2003        1                     середня загальноосвітня школа
# 4        2002        0                                          гімназія
# ...       ...      ...                                               ...
# 780646   2006        1                     середня загальноосвітня школа
# 780647   2004        1                                              None
# 780648   2006        0                     середня загальноосвітня школа
# 780649   2004        1  заклад професійної (професійно-технічної) освіти
# 780650   2006        1                                             ліцей
#
#                     SchoolRegion                      SchoolArea    Ukr  \
# ...

# %%
merged_df.to_csv('data.csv', index=False, sep=';', encoding='utf-8')
merged_df.to_parquet('data_parquet.parquet', index=False)
